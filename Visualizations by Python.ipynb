# %%
import os  # for input-Output operations

# %%
from pandas import Timestamp

# %%
from ggplot import *

# %%
import numpy as np  # for all numerical operations

# %%
import pandas as pd   # for dataFrame operations

# %%
from sklearn.metrics import accuracy_score    #for Accurancy and FNR statistical operations

# %%
from scipy.stats import chi2_contingency  # for chi-sqr test and comtingency table

# %%
import seaborn as sns

# %%
os.chdir('C:\\Users\\patil\\Downloads\\DS_works\\DataSets')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\patil\\Downloads\\DS_works\\DataSets'

# %%
marketing_train = pd.read_csv("marktrain_Normalized.csv")

# %% [markdown]
# ## ggplot- BAR graph

# %%
#bar plot
ggplot(marketing_train, aes(x='profession', y='campaign')) +\
    geom_bar(fill= "DarkSlateBlue") +\
    scale_color_brewer(type='diverging', palette=4) +\
    xlab("Profession") + ylab("Campaign") + ggtitle("Marketing Analysis") + theme_bw()
# Out:
# <ggplot: (-9223371917911394055)>

# %% [markdown]
# ## Histogram

# %%
#Histogram 
ggplot(marketing_train, aes(x = 'custAge')) + geom_histogram(fill="DarkSlateBlue", colour = "black") +\
    geom_density() +\
    theme_bw() + xlab("Age") + ylab("Frequency") + ggtitle("Marketing Campaign Analysis") +\
    theme(text=element_text(size=20))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ggplot\themes\theme.py:134: RuntimeWarning: text is an invalid theme parameter
#   warnings.warn(msg, RuntimeWarning)
# <ggplot: (-9223371917911394153)>

# %% [markdown]
# ## Box-Plot

# %%
##Box plot
ggplot(marketing_train, aes(x = 'responded', y = 'custAge', fill = 'responded')) +\
    geom_boxplot(fill = 'responded')+ theme_bw() + xlab("Responded") + ylab("Customer Age") +\
    ggtitle("Outlier Analysis") +\
    theme(text=element_text(size=30))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ggplot\themes\theme.py:134: RuntimeWarning: text is an invalid theme parameter
#   warnings.warn(msg, RuntimeWarning)
# <ggplot: (-9223371917911313085)>

# %% [markdown]
# ## Scatter Plot

# %%
#Multivariate #Scatter Plot 
ggplot(marketing_train, aes(x = 'campaign', y = 'custAge', color='responded')) + \
    geom_point(alpha = 1, size = 50) + theme_bw()+ ylab("Age") + xlab("Campaign") + ggtitle("Scatter Plot Analysis")
# Out:
# <ggplot: (118943567957)>

# %%
#Multivariate #Scatter Plot 
#shape = 'profession'  
ggplot(marketing_train, aes(x = 'campaign', y = 'custAge', color='responded')) + \
    geom_point(alpha = 1, size = 50) + theme_bw()+ ylab("Age") + xlab("Campaign") + ggtitle("Scatter Plot Analysis")
# Out:
# <ggplot: (-9223371917911030307)>
