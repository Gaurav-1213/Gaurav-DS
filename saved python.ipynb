# %%
import os

# %%
os.chdir("C://Users//patil//OneDrive//Documents//R//win-library//3.6//xlsx//R")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\patil\\OneDrive\\Documents\\R\\win-library\\3.6\\xlsx\\R'

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as mlt

# %%
df_csv2=pd.read_csv("IMDB_data.csv",sep=",")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa3 in position 127: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-14-db995d47fdf2> in <module>
# ----> 1 df_csv2=pd.read_csv("IMDB_data.csv",sep=",")
#
# ...

# %%
df_csv2=df_csv2.sort_values('Genres')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-33663166cc6b> in <module>
# ----> 1 df_csv2=df_csv2.sort_values('Genres')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'Genres'

# %%
data = pd.read_csv('https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/64f1660f38ef523b2a1a13be77b002b98665cdfe/mtcars.csv')

# %%
df_csv2
# Out:
#                                                    Plot  \
# 0     Despite his tarnished reputation after the eve...
# 1     Based on the novel written by Stephen Chbosky,...
# 2     Mike Lane is a thirty-year old living in Tampa...
# 3     When Bond's latest assignment goes gravely wro...
# 4     Against medical advice and without the knowled...
# ...                                                 ...
# 3384  Vikram Rathod, A sincere Police man joins with...
# 3385  After an eventful train trip on the Visakha/Ra...
# 3386  Mahi is a beautiful wealthy heiress, but her f...
# 3387  Yevade Subramanyam has wrapped its shooting an...
# 3388  Sathya (Allu Arjun) returns from a coma to tak...
#
#                                 Title imdbVotes  \
# 0               The Dark Knight Rises      2679
# 1     The Perks of Being a Wallflower      1270
# 2                          Magic Mike      2580
# 3                             Skyfall      1807
# ...

# %%
df_csv2[:]
# Out:
#                                                       0  \
# 0     Based on the novel written by Stephen Chbosky,...
# 1     Mike Lane is a thirty-year old living in Tampa...
# 2     When Bond's latest assignment goes gravely wro...
# 3     Against medical advice and without the knowled...
# 4     A shy senior and a down-to-earth junior fall i...
# ...                                                 ...
# 3383  Vikram Rathod, A sincere Police man joins with...
# 3384  After an eventful train trip on the Visakha/Ra...
# 3385  Mahi is a beautiful wealthy heiress, but her f...
# 3386  Yevade Subramanyam has wrapped its shooting an...
# 3387  Sathya (Allu Arjun) returns from a coma to tak...
#
#                                   0.1    0.2  \
# 0     The Perks of Being a Wallflower   1270
# 1                          Magic Mike   2580
# 2                             Skyfall   1807
# 3             Silver Linings Playbook   1828
# 4                      The First Time   1538
# ...

# %%
df_csv.to_csv("imdbdata2.csv",index=True)

# %%
df_csv
# Out:
#      Despite his tarnished reputation after the events of The Dark Knight, in which he took the rap for Dent's crimes, Batman feels compelled to intervene to assist the city and its police force which is struggling to cope with Bane's plans to destroy the city.  \
# 0                                                     0
# 1     Based on the novel written by Stephen Chbosky,...
# 2     Mike Lane is a thirty-year old living in Tampa...
# 3     When Bond's latest assignment goes gravely wro...
# 4     Against medical advice and without the knowled...
# ...                                                 ...
# 3384  Vikram Rathod, A sincere Police man joins with...
# 3385  After an eventful train trip on the Visakha/Ra...
# 3386  Mahi is a beautiful wealthy heiress, but her f...
# 3387  Yevade Subramanyam has wrapped its shooting an...
# 3388  Sathya (Allu Arjun) returns from a coma to tak...
#
#                 The Dark Knight Rises   2679  \
# ...

# %%
df

# %%
import pandas as pd

# %%
df_csv=pd.read_csv("data_output.csv",sep=',',unicode='Latin=1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9e1fe89c69b7> in <module>
# ----> 1 df_csv=pd.read_csv("data_output.csv",sep=',',unicode='Latin=1')
#
# TypeError: parser_f() got an unexpected keyword argument 'unicode'

# %%
df_csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5d6b8269310f> in <module>
# ----> 1 df_csv
#
# NameError: name 'df_csv' is not defined

# %%
type(df_csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5a9fb9b42612> in <module>
# ----> 1 type(df_csv)
#
# NameError: name 'df_csv' is not defined

# %%
df_csv.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
df_csv.shape
# Out:
# (32, 12)

# %%
df_csv.tail(3)
# Out:
#        Unnamed: 0   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 29   Ferrari Dino  19.7    6  145.0  175  3.62  2.77  15.5   0   1     5     6
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# 31     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %%
df_csv.head(3)
# Out:
#       Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
df_csv.iloc[:,:4]
# Out:
#              Unnamed: 0   mpg  cyl   disp
# 0             Mazda RX4  21.0    6  160.0
# 1         Mazda RX4 Wag  21.0    6  160.0
# 2            Datsun 710  22.8    4  108.0
# 3        Hornet 4 Drive  21.4    6  258.0
# 4     Hornet Sportabout  18.7    8  360.0
# 5               Valiant  18.1    6  225.0
# 6            Duster 360  14.3    8  360.0
# 7             Merc 240D  24.4    4  146.7
# 8              Merc 230  22.8    4  140.8
# 9              Merc 280  19.2    6  167.6
# 10            Merc 280C  17.8    6  167.6
# 11           Merc 450SE  16.4    8  275.8
# 12           Merc 450SL  17.3    8  275.8
# 13          Merc 450SLC  15.2    8  275.8
# 14   Cadillac Fleetwood  10.4    8  472.0
# 15  Lincoln Continental  10.4    8  460.0
# 16    Chrysler Imperial  14.7    8  440.0
# 17             Fiat 128  32.4    4   78.7
# 18          Honda Civic  30.4    4   75.7
# 19       Toyota Corolla  33.9    4   71.1
# 20        Toyota Corona  21.5    4  120.1
# ...

# %%
df_csv['cyl'].nunique()
# Out:
# 3

# %%
df_csv['cyl'].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
df_csv['cyl'].describe()
# Out:
# count    32.000000
# mean      6.187500
# std       1.785922
# min       4.000000
# 25%       4.000000
# 50%       6.000000
# 75%       8.000000
# max       8.000000
# Name: cyl, dtype: float64

# %%
test[1,4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3ac6417dd36d> in <module>
# ----> 1 test[1,4]
#
# NameError: name 'test' is not defined

# %%
str(df_csv)
# Out:
# '             Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \\\n0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1   \n1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1   \n2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1   \n3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0   \n4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0   \n5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0   \n6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0   \n7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0   \n8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0   \n9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0   \n10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0   \n11           Merc 450SE  16.4    8  275.8  180  
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\patil\\OneDrive\\Documents\\R\\win-library\\3.6\\xlsx\\R'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\patil'
